# %% [markdown]
# ###Importing Pyspark Functions

# %%
from pyspark.sql.functions import *

# %% [markdown]
# ###Reading the transactions file

# %%
tran_df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/Volumes/retail_analytics/raw/kaggle/global_fashion/transactions.csv")

# %%
display(tran_df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Invoice ID</th><th>Line</th><th>Customer ID</th><th>Product ID</th><th>Size</th><th>Color</th><th>Unit Price</th><th>Quantity</th><th>Date</th><th>Discount</th><th>Line Total</th><th>Store ID</th><th>Employee ID</th><th>Currency</th><th>Currency Symbol</th><th>SKU</th><th>Transaction Type</th><th>Payment Method</th><th>Invoice Total</th></tr></thead><tbody><tr><td>INV-US-001-03558761</td><td>1</td><td>47162</td><td>485</td><td>M</td><td>null</td><td>80.5</td><td>1</td><td>2023-01-01T15:42:00.000Z</td><td>0.0</td><td>80.5</td><td>1</td><td>7</td><td>USD</td><td>$</td><td>MASU485-M-</td><td>Sale</td><td>Cash</td><td>126.7</td></tr><tr><td>INV-US-001-03558761</td><td>2</td><td>47162</td><td>2779</td><td>G</td><td>null</td><td>31.5</td><td>1</td><td>2023-01-01T15:42:00.000Z</td><td>0.4</td><td>18.9</td><td>1</td><td>7</td><td>USD</td><td>$</td><td>CHCO2779-G-</td><td>Sale</td><td>Cash</td><td>126.7</td></tr><tr><td>INV-US-001-03558761</td><td>3</td><td>47162</td><td>64</td><td>M</td><td>NEUTRAL</td><td>45.5</td><td>1</td><td>2023-01-01T15:42:00.000Z</td><td>0.4</td><td>27.3</td><td>1</td><td>7</td><td>USD</td><td>$</td><td>MACO64-M-NEUTRAL</td><td>Sale</td><td>Cash</td><td>126.7</td></tr><tr><td>INV-US-001-03558762</td><td>1</td><td>10142</td><td>131</td><td>M</td><td>BLUE</td><td>70.0</td><td>1</td><td>2023-01-01T20:04:00.000Z</td><td>0.4</td><td>42.0</td><td>1</td><td>6</td><td>USD</td><td>$</td><td>FECO131-M-BLUE</td><td>Sale</td><td>Cash</td><td>77.0</td></tr><tr><td>INV-US-001-03558762</td><td>2</td><td>10142</td><td>716</td><td>L</td><td>WHITE</td><td>26.0</td><td>1</td><td>2023-01-01T20:04:00.000Z</td><td>0.0</td><td>26.0</td><td>1</td><td>6</td><td>USD</td><td>$</td><td>MAT-716-L-WHITE</td><td>Sale</td><td>Cash</td><td>77.0</td></tr></tbody></table></div>

# %% [markdown]
# ### Import Python's regular expression module

# %%
import re

# %% [markdown]
# ###Fixing the column name issue

# %%
# Clean column names
clean_columns = [re.sub(r'[ ,;{}()\n\t=]', '_', c) for c in tran_df.columns]
tran_df = tran_df.toDF(*clean_columns)

# Add ingestion timestamp
tran_df = tran_df.withColumn("ingestion_ts", current_timestamp())

# %% [markdown]
# ###Saving the table

# %%
(tran_df.write
 .format("delta")
 .mode("overwrite")
 .saveAsTable("retail_analytics.bronze.transactions")
)

# %%
spark.read.table("retail_analytics.bronze.transactions").limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Invo