# %% [markdown]
# ###Importing the modules

# %%
from pyspark.sql.functions import *
from delta.tables import DeltaTable

# %% [markdown]
# ###Reading Return data from silver layer

# %%
returns_df = (
    spark.read.table("retail_analytics.silver.transactions")
    .filter(upper(col("transaction_type")) == "RETURN")
)

# %%
returns_df.count()
# Out:
# 338829

# %% [markdown]
# ###Creating date_sk from date column

# %%
returns_df = returns_df.withColumn(
    "date_sk",
    date_format(to_date(col("date")), "yyyyMMdd").cast("int")
)

# %% [markdown]
# ###Joining Dimension tables

# %%
fact_joined_df = (
    returns_df.alias("r")
    .join(
        spark.table("retail_analytics.gold.dim_customers").alias("c"),
        col("r.customer_id") == col("c.customer_id"),
        "left"
    )
    .join(
        spark.table("retail_analytics.gold.dim_products").alias("p"),
        col("r.product_id") == col("p.product_id"),
        "left"
    )
    .join(
        spark.table("retail_analytics.gold.dim_stores").alias("s"),
        col("r.store_id") == col("s.store_id"),
        "left"
    )
    .join(
        spark.table("retail_analytics.gold.dim_employees").alias("e"),
        col("r.employee_id") == col("e.employee_id"),
        "left"
    )
)

# %% [markdown]
# ###Selecting the needed columns

# %%
fact_returns_df = (
    fact_joined_df.select(
        col("r.date_sk"),
        col("c.customer_sk"),
        col("p.product_sk"),
        col("s.store_sk"),
        col("e.employee_sk"),
        col("r.invoice_id"),
        col("r.line"),
        col("r.size"),
        col("r.quantity").alias("quantity_returned"),
        col("r.line_total").alias("refund_amount"),
        col("r.currency"),
        col("r.date").alias("return_date"),
        current_timestamp().alias("_created_at")
    )
)

# %% [markdown]
# ###Creating fact_return with sk key

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS retail_analytics.gold.fact_returns (
    return_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    date_sk INT,
    customer_sk BIGINT,
    product_sk BIGINT,
    store_sk BIGINT,
    employee_sk BIGINT,
    invoice_id STRING,
    line INT,
    size STRING,
    quantity_returned INT,
    refund_amount DOUBLE,
    currency STRING,
    return_date TIMESTAMP,
    _created_at TIMESTAMP
)
USING DELTA
""")
# Out:
# DataFrame[]

# %% [markdown]
# ###Merge process(SCD-1)

# %%
fact_returns_tbl = DeltaTable.forName(
    spark, "retail_analytics.gold.fact_returns"
)

(
    fact_returns_tbl.alias("tgt")
    .merge(
        fact_returns_df.alias("src"),
        """
        tgt.invoice_id = src.invoice_id AND
        tgt.line = src.line AND
        tgt.return_date = src.return_date
        """
    )
    .whenNotMatchedInsert(values={
        "date_sk": col("src.date_sk"),
        "customer_sk": col("src.customer_sk"),
        "product_sk": col("src.product_sk"),
        "store_sk": col("src.store_sk"),
        "employee_sk": col("src.employee_sk"),
        "invoice_id": col("src.invoice_id"),
        "line": col("src.line"),
        "size": col("src.size"),
        "quantity_returned": col("src.quantity_returned"),
        "refund_amount": col("src.refund_amount"),
        "currency": col("src.currency"),
        "return_date": col("src.return_date"),
        "_created_at": col("src._created_at")
    })
    .execute()
)
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]

# %%
spark.read.table("retail_analytics.gold.fact_returns").limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>return_sk</th><th>date_sk</th><th>customer_sk</th><th>product_sk</th><th>store_sk</th><th>employee_sk</th><th>invoice_id</th><th>line</th><th>size</th><th>quantity_returned</th><th>refund_amount</th><th>currency</th><th>return_date</th><th>_created_at</th></tr></thead><tbody><tr><td>1</td><td>20241228</td><td>357384</td><td>8788</td><td>33</td><td>61</td><td>RET-US-005-04350283</td><td>1</td><td>S</td><td>1</td><td>-21.0</td><td>USD</td><td>2024-12-28T00:00:00.000Z</td><td>2026-01-20T10:37:09.853Z</td></tr><tr><td>3</td><td>20250126</td><td>1191820</td><td>2929</td><td>33</td><td>13</td><td>RET-US-005-04355995</td><td>3</td><td>M</td><td>1</td><td>-81.0</td><td>USD</td><td>2025-01-26T00:00:00.000Z</td><td>2026-01-20T10:37:09.853Z</td></tr><tr><td>5</td><td>20230119</td><td>5884</td><td>3730</td><td>15</td><td>73</td><td>RET-CN-006-02868410</td><td>1</td><td>M</td><td>1</td><td>-125.0</td><td>CNY</td><td>2023-01-19T00:00:00.000Z</td><td>2026-01-20T10:37:09.853Z</td></tr><tr><td>7</td><td>20230326</td><td>249322</td><td>15617</td><td>15</td><td>271</td><td>RET-CN-006-02882457</td><td>5</td><td>M</td><td>1</td><td>-163.0</td><td>CNY</td><td>2023-03-26T00:00:00.000Z</td><td>2026-01-20T10:37:09.853Z</td></tr><tr><td>9</td><td>20230916</td><td>1226113</td><td>4247</td><td>15</td><td>254</td><td>RET-CN-006-02920008</td><td>2</td><td>XL</td><td>1</td><td>-250.0</td><td>CNY</td><td>2023-09-16T00:00:00.000Z</td><td>2026-01-20T10:37:09.853Z</td></tr></tbody></table></div>

# %%
spark.read.table("retail_analytics.gold.fact_returns").count()
# Out:
# 338829
